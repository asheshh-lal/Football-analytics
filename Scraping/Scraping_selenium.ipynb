# %%
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import requests

# %%
# Initialize the Chrome webdriver with capabilities
# driver = webdriver.Chrome("/Users/asheshlalshrestha/Desktop/Datanal/Project/Football-analytics/Webdrivers/chromedriver2")

# %%
driver = webdriver.Chrome()
url = "https://www.serebii.net/pokemon/gen1pokemon.shtml"
driver.get(url)
# driver.quit()

# %%
from bs4 import BeautifulSoup

# %%
page_source = BeautifulSoup(driver.page_source,'html.parser')

# %%
pokemon = page_source.select('table[class="dextable"] tbody tr')

# %%
pokemon
# Out:
# [<tr>
#  <td align="center" class="fooevo" rowspan="2">
#  		No.
#  		</td>
#  <td align="center" class="fooevo" rowspan="2" width="32">
#  		Pic
#  		</td>
#  <td align="center" class="fooevo" rowspan="2">
#  		Name
#  		</td>
#  <td align="center" class="fooevo" rowspan="2">
#  		Type
#  		</td>
#  <td align="center" class="fooevo" rowspan="2" width="10%">
#  		Abilities
#  		</td>
#  <td align="center" class="fooevo" colspan="6" width="10%">
#  		Base Stats
#  		</td>
#  </tr>,
#  <tr>
#  <td align="center" class="fooevo">HP</td>
#  <td align="center" class="fooevo">Att</td>
#  <td align="center" class="fooevo">Def</td>
#  <td align="center" class="fooevo">S.Att</td>
#  <td align="center" class="fooevo">S.Def</td>
#  <td align="center" class="fooevo">Spd</td>
#  </tr>,
#  <tr>
#  <td align="center" class="fooinfo">
#  		#0001
#  		</td>
# ...

# %%
poke2 = str(pokemon)

# %%
html_wrapped = StringIO(poke2)
html_wrapped

# %%
data = pd.read_html("https://www.serebii.net/pokemon/gen1pokemon.shtml")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data = pd.read_html("https://www.serebii.net/pokemon/gen1pokemon.shtml")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/html.py:1246, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1230 if isinstance(io, str) and not any(
#    1231     [
#    1232         is_file_like(io),
#    (...)
#    1236     ]
#    1237 ):
#    1238     warnings.warn(
#    1239         "Passing literal html to 'read_html' is deprecated and "
#    1240         "will be removed in a future version. To read from a "
#    (...)
#    1243         stacklevel=find_stack_level(),
#    1244     )
# -> 1246 return _parse(
#    1247     flavor=flavor,
# ...

# %%
data = requests.get("https://fbref.com/en/squads/19538871/2021-2022/Manchester-United-Stats")

matches = pd.read_html(data.text, match='Scores & Fixtures')
# Out:
# /var/folders/9b/q0txn0fd5qj57z36hsjf2yxh0000gn/T/ipykernel_39150/3941186460.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match='Scores & Fixtures')

# %%
matches[0]
# Out:
#           Date   Time            Comp                Round  Day Venue Result  \
# 0   2021-08-14  12:30  Premier League          Matchweek 1  Sat  Home      W
# 1   2021-08-22  14:00  Premier League          Matchweek 2  Sun  Away      D
# 2   2021-08-29  16:30  Premier League          Matchweek 3  Sun  Away      W
# 3   2021-09-11  15:00  Premier League          Matchweek 4  Sat  Home      W
# 4   2021-09-14  18:45    Champions Lg          Group stage  Tue  Away      L
# 5   2021-09-19  14:00  Premier League          Matchweek 5  Sun  Away      W
# 6   2021-09-22  19:45         EFL Cup          Third round  Wed  Home      L
# 7   2021-09-25  12:30  Premier League          Matchweek 6  Sat  Home      L
# 8   2021-09-29  20:00    Champions Lg          Group stage  Wed  Home      W
# 9   2021-10-02  12:30  Premier League          Matchweek 7  Sat  Home      D
# 10  2021-10-16  15:00  Premier League          Matchweek 8  Sat  Away      L
# ...

# %%
matches = pd.read_html(data.text, match='Shooting')
# Out:
# /var/folders/9b/q0txn0fd5qj57z36hsjf2yxh0000gn/T/ipykernel_39150/2667860461.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match='Shooting')

# %%
matches[0]
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Player             Nation                Pos
# 0         David de Gea             es ESP                 GK
# 1      Bruno Fernandes             pt POR                 MF
# 2        Harry Maguire            eng ENG                 DF
# 3      Scott McTominay            sct SCO                 MF
# 4    Cristiano Ronaldo             pt POR                 FW
# 5      Victor Lindelöf             se SWE                 DF
# 6                 Fred             br BRA                 MF
# 7         Jadon Sancho            eng ENG              FW,MF
# 8       Raphaël Varane             fr FRA                 DF
# 9    Aaron Wan-Bissaka            eng ENG                 DF
# 10         Diogo Dalot             pt POR                 DF
# 11           Luke Shaw            eng ENG                 DF
# 12         Alex Telles             br BRA                 DF
# ...

# %%
data = requests.get("https://fbref.com/en/squads/19538871/2022-2023/matchlogs/all_comps/shooting/Manchester-United-Match-Logs-All-Competitions")

matches = pd.read_html(data.text, match='Agianst Manchester United')
# Out:
# /var/folders/9b/q0txn0fd5qj57z36hsjf2yxh0000gn/T/ipykernel_39150/3180494919.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match='Agianst Manchester United')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 3
#       1 data = requests.get("https://fbref.com/en/squads/19538871/2022-2023/matchlogs/all_comps/shooting/Manchester-United-Match-Logs-All-Competitions")
# ----> 3 matches = pd.read_html(data.text, match='Agianst Manchester United')
#
# ...

# %%
matches[0]
# Out:
#    For Manchester United                                                     \
#                     Date   Time            Comp         Round  Day    Venue
# 0             2022-08-07  14:00  Premier League   Matchweek 1  Sun     Home
# 1             2022-08-13  17:30  Premier League   Matchweek 2  Sat     Away
# 2             2022-08-22  20:00  Premier League   Matchweek 3  Mon     Home
# 3             2022-08-27  12:30  Premier League   Matchweek 4  Sat     Away
# 4             2022-09-01  20:00  Premier League   Matchweek 5  Thu     Away
# ..                   ...    ...             ...           ...  ...      ...
# 58            2023-05-20  15:00  Premier League  Matchweek 37  Sat     Away
# 59            2023-05-25  20:00  Premier League  Matchweek 32  Thu     Home
# 60            2023-05-28  16:30  Premier League  Matchweek 38  Sun     Home
# 61            2023-06-03  15:00          FA Cup         Final  Sat  Neutral
# ...
